# %%
import pandas as pd 

FILE_PATH = "C:\CIL\CSV"  
CRM_file = FILE_PATH + '\Contacts.csv'

df_crm = pd.read_csv(CRM_file)

df_crm.drop(["Email 1 Other","Email 2 Other","Email 3 Other","Email 4 Other","Email 5 Home", "Email 7 Work","Email 8 Work","Email 9 Work","Phone 1 Other","Phone 2 Other","Phone 3 Other","Phone 4 Other","Phone 5 Other","Phone 6 Other","Phone 7 Direct","Phone 8 Work","Phone 9 Work","Phone 10 Mobile","Web 1 Website","Web 2 Website","Web 3 Website","Web 4 Website","Web 5 Other","Web 6 Other","Web 7 Other","Web 8 Other","Web 9 Other","Web 10 Other","Web 11 Other","Web 12 Other","Web 13 Other","Web 14 Other","Web 15 Other","Web 16 Other","Web 17 Other","Web 18 Other","Web 19 Other","Web 20 Other","Web 21 Other","Web 22 Facebook","Web 23 Facebook","Web 24 Linkedin","Web 25 Linkedin","Web 26 Linkedin","Web 27 Linkedin","Web 28 Linkedin","Web 29 Twitter","Web 30 Twitter","Web 31 Blog","Address 1 Work","City 1 Work","State 1 Work","Zip 1 Work","Country 1 Work","Address 2 Work","City 2 Work","State 2 Work","Zip 2 Work","Country 2 Work","Background","Added","Tags","Lead source","Owner","Birthday","Organization description","Organization phone","Organization URL","Organization address","Organization city","Organization state","Organization zip","Organization country","Org Hourly Rate"],axis = 1, inplace=True)
display(df_crm)
lookup = df_crm[['First name', 'Last name', 'Email 6 Work', 'Status']]

p_p = lookup.query("Status == 'Potential Partner'")

display(p_p)
# Out:
#                     Contact ID   First name   Last name  \
# 0     5cdaf05bd31bb551138e4fc2  Christopher        Hund
# 1     5cdaf05bd31bb551138e4fcd       Gibran  Hadj Chikh
# 2     5cdaf05bd31bb551138e4fe4         Bill      Fienup
# 3     5cdaf05bd31bb551138e4fec        Jason      Kehrer
# 4     5cdaf05bd31bb551138e4fef          Ben     Brenton
# ...                        ...          ...         ...
# 4218  619bade62b95af183d7e77fb        Kevin     Sellars
# 4219  61b3bba82b95af706e101800          Rob   Ostermann
# 4220  61f846c488d0cd5db20f8789         Todd   VanHouten
# 4221  61f8476588d0cd5d8a3128a0         Rick       Tucci
# 4222  61f8478d88d0cd5d8a312caa          Sam   Kasgorgis
#
#                                               Job Title  \
# 0     Director of Programming & Implementation with ...
# 1     Vice President - Strategic Transformation & In...
# 2        Co-Founder and Director of Innovation Services
# 3                                  Director, Innovation
# ...
