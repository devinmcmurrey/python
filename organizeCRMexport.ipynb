# %%
import pandas as pd 

FILE_PATH = "C:\CIL\CSV"
    
crm_file = FILE_PATH + '\OrganizeCRM.csv'

df_crm = pd.read_csv(crm_file)

df_crm= df_crm.drop(['9','10'], axis = 1)

display(df_crm)
# Out:
#               Prospect_Name          Business_Name Follow_up_Status  \
# 0             Fedor Erashev              WorkoutMe             warm
# 1           Catherine Braun        Purpose Driven              warm
# 2             Justin Bowers        Captiv Creative             warm
# 3   Margaret (Marks) Gibson           CrowdHealrth             warm
# 4              Raghwa Gopal            Innovate BC             warm
# 5            Dude Spellings             Tradelines             warm
# 6             Brian Bristol         Pidgeon Loans              warm
# 7             Marvin Walker                DayKare             open
# 8               Dano Ybarra                 MyHibe             open
# 9                Tylor Hunn              SpareTime             open
# 10                Omer Matz              Indieflow             open
# 11         Rebecca McDowell                 Summon             open
# 12               Shanna Liu                   Seek             open
# ...
